# %%
import os
path = '/home/ramya/Desktop/Projects/Mitosis_cancer/'
from PIL import Image
path =path+'output1/'
for filename in os.listdir(path):
    filename1=path+filename
    img = Image.open((filename1))
    print(filename1)
    red, green, blue = img.split()
    save_path='redoutput1/'+filename
    red.save(save_path,'')
# Out:
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_00Cb0false.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A04_07Aa12false.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_02Ad16true.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_00Dd58false.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_00Ca17false.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_02Bc17true.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A04_05Ac20true.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A04_06Bb9true.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_01Cb11false.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A04_06Bb10true.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_01Ac4false.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_00Bb22false.png
# /home/ramya/Desktop/Projects/Mitosis_cancer/output1/A03_01Ab31false.png
# ...
